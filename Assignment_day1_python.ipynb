# %% [markdown]
# 1) After running the following code, what does the variable bacon contain?
#
# bacon = 22
#
# bacon + 1

# %% [markdown]
# answer = 22

# %% [markdown]
# 2) What should the values of the following two terms be?
#
# 'spam' + 'spamspam'
#
# 'spam' * 3

# %% [markdown]
# both will give 'spamspamspam'

# %% [markdown]
# 3) How can you tell the difference between break and continue?

# %% [markdown]
# Break will leave the loop and execute the statemestatements after the loop while Continue eaves the current iteration and executes with the next value in the loop.

# %% [markdown]
# 4) In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?

# %% [markdown]
# #First range function range(10) takes one argument only and known as range(stop) function. It means the range of integers end at stop – 1.
#
# #Second range function range(1,10) takes two arguments and is range(start,stop) function. It means it start the loop from 1 and stop at 9.
#
# #Third range function range(1,10,1) takes three arguments and is range(start,stop,step) function. It means it start the loop from 1  increment 1 in the sequence and stop at 9

# %% [markdown]
# 5) Using a for loop, write a short programme that prints the numbers 1 to 10 Then, using a while loop, create an identical programme that prints the numbers 1 to 10.

# %%
for i in range(1,11):
    print(i)

# %%
a = 1
while(a<=10):
    print(a)
    a= a+1

# %% [markdown]
# 6) Given a number x, determine whether the given number is Armstrong number or not.
#
# Input : 153
#
# Output : Yes
#
# 153 is an Armstrong number.
#
# 1 * 1 * 1 + 5 * 5 * 5 + 3 * 3 * 3 = 153

# %%
num = input("enter a no. ")

n = int(num)
y = len(num)
sum = 0
for a in num:
    b = int(a)
    sum = sum + b**y
if (sum == n):
    print("Armstrong number")
else:
    print("Not an Armstrong number")

# %% [markdown]
# 7) Program to find Sum of squares of first n natural numbers.

# %%
n = int(input("Enter the number: "))
sum = 0
for i in range(1,n+1):
    sum = sum + i**2
print("The sum of square of numbers from 1 to ", n ,"is :" , sum)

# %% [markdown]
# 8) Program to Reverse words in a given String in Python.

# %%
st = input()
print(st[::-1])

# %% [markdown]
# 9) Given a list of numbers, write a Python program to find the sum of all the elements in the list.
#
# Input: [10,12,13]
#
# Output: 35

# %%
input = [10,12,13]
sum = 0
for y in input:
    sum = sum+ y
print(sum)

# %% [markdown]
# 10) Write a Python program to print all even numbers between 10-1000.

# %%
for e in range (10,1000):
    if (e%2 == 0):
        print(e , end =",")
    else:
        continue
